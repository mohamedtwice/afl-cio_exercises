# %%
import pandas as pd
import numpy as np
import xlsxwriter

# %%
v12 = pd.read_csv('Volunteers 1.1.12-12.31.12.csv')
v14 = pd.read_csv('Volunteers 1.1.14-12.31.14.csv')
v12_14 = pd.concat([v12, v14])

# %%
v12_14.columns
# Out:
# Index([u'MyCampaignID', u'International Name', u'Local Name',
#        u'Participant Local', u'Participant International', u'EventType',
#        u'EventName', u'Shift', u'EventDescription', u'StartDate', u'StartTime',
#        u'EndDate', u'EndTime', u'Role', u'Status', u'Home City', u'Home State',
#        u'DateRecruited', u'LastContactedBy', u'DateLastContacted',
#        u'InputType '],
#       dtype='object')

# %%
v12_14.columns = v12_14.columns.str.replace(' ', '_')

# %%
v12_14.columns
# Out:
# Index([u'MyCampaignID', u'International_Name', u'Local_Name',
#        u'Participant_Local', u'Participant_International', u'EventType',
#        u'EventName', u'Shift', u'EventDescription', u'StartDate', u'StartTime',
#        u'EndDate', u'EndTime', u'Role', u'Status', u'Home_City', u'Home_State',
#        u'DateRecruited', u'LastContactedBy', u'DateLastContacted',
#        u'InputType_'],
#       dtype='object')

# %%
v12_14['Home_State'].unique()
# Out:
# array(['FL', 'NC', 'OH', 'WI', 'MO', 'PA', 'NV', 'Ft Lauderdale',
#        'Sunrise', 'Hollywood'], dtype=object)

# %%
v12_14[v12_14['Home_State'] == 'Sunrise']
# Out:
#        MyCampaignID International_Name Local_Name Participant_Local  \
# 24132     103088713                NaN        NaN               NaN
#
#       Participant_International  EventType              EventName Shift  \
# 24132                       NaN  Political  Canvassing in Broward     1
#
#                                         EventDescription  \
# 24132  Do you support President Obama or Mitt Romney?...
#
#                                                StartDate    ...       EndDate  \
# 24132    Do you support or oppose Florida Constitutio...    ...      14:00:00
#
#        EndTime  Role Status                    Home_City Home_State  \
# 24132  9/29/12  4582  Walks  2901 N Nob Hill Rd Apt 209     Sunrise
#
#          DateRecruited LastContactedBy DateLastContacted InputType_
# 24132  Crosson, Walter   9/29/12 17:49               NaN        NaN
#
# [1 rows x 21 columns]

# %%
# Confirming 
v12_14[v12_14['EventName'] == 'Canvassing in Broward']
# Out:
#        MyCampaignID International_Name Local_Name Participant_Local  \
# 5751      103113016               IBEW        728               NaN
# 11983     101691855               NALC       1071               NaN
# 24057     103125512                NaN        NaN               NaN
# 24058     103125512                NaN        NaN               NaN
# 24059     103128969                NaN        NaN               NaN
# 24060     103128969                NaN        NaN               NaN
# 24061     103119735                NaN        NaN               NaN
# 24062     103119735                NaN        NaN               NaN
# 24063     103119735                NaN        NaN               NaN
# 24064     103119735                NaN        NaN               NaN
# 24065     103119728                NaN        NaN               NaN
# 24066     103119728                NaN        NaN               NaN
# 24067     103119728                NaN        NaN               NaN
# ...

# %%
v12_14[v12_14['Home_State'] == 'Hollywood']
# Out:
#        MyCampaignID International_Name Local_Name Participant_Local  \
# 54215     103087883             AFSCME       2009               NaN
#
#       Participant_International  EventType              EventName Shift  \
# 54215                       NaN  Political  Canvassing in Broward     1
#
#                                         EventDescription  \
# 54215  Do you support President Obama or Mitt Romney?...
#
#                                                StartDate    ...       EndDate  \
# 54215    Do you support or oppose Florida Constitutio...    ...      14:00:00
#
#        EndTime  Role Status        Home_City Home_State    DateRecruited  \
# 54215  9/29/12  4582  Walks  901 S 29th Ave   Hollywood  Crosson, Walter
#
#       LastContactedBy DateLastContacted InputType_
# 54215   9/29/12 18:04               NaN        NaN
#
# [1 rows x 21 columns]

# %%
v12_14[v12_14['Home_State'] == 'Ft Lauderdale']
# Out:
#        MyCampaignID International_Name Local_Name Participant_Local  \
# 24130     103081077                NaN        NaN               NaN
# 24131     103088707                NaN        NaN               NaN
#
#       Participant_International  EventType              EventName Shift  \
# 24130                       NaN  Political  Canvassing in Broward     1
# 24131                       NaN  Political  Canvassing in Broward     1
#
#                                         EventDescription  \
# 24130  Do you support President Obama or Mitt Romney?...
# 24131  Do you support President Obama or Mitt Romney?...
#
#                                                StartDate    ...       EndDate  \
# 24130    Do you support or oppose Florida Constitutio...    ...      14:00:00
# 24131    Do you support or oppose Florida Constitutio...    ...      14:00:00
#
#        EndTime  Role Status                Home_City     Home_State  \
# ...

# %%
v12_14['Home_State'].replace(['Hollywood'],['FL'],inplace=True)
v12_14['Home_State'].replace(['Ft Lauderdale'], ['FL'],inplace=True)
v12_14['Home_State'].replace(['Sunrise'], ['FL'],inplace=True)

# %%
v12_14[('Home_State')].unique()
# Out:
# array(['FL', 'NC', 'OH', 'WI', 'MO', 'PA', 'NV'], dtype=object)

# %%
fl_file = v12_14[v12_14['Home_State'].isin(['FL'])].copy()
nc_file = v12_14[v12_14['Home_State'].isin(['NC'])].copy()
oh_file = v12_14[v12_14['Home_State'].isin(['OH'])].copy()
wi_file = v12_14[v12_14['Home_State'].isin(['WI'])].copy()
mo_file = v12_14[v12_14['Home_State'].isin(['MO'])].copy()
pa_file = v12_14[v12_14['Home_State'].isin(['PA'])].copy()
nv_file = v12_14[v12_14['Home_State'].isin(['NV'])].copy()

# %%
nv_file.tail()
# Out:
#        MyCampaignID International_Name Local_Name Participant_Local  \
# 30572     103053729                 UA        525               NaN
# 30573     103218417                 UA        525               NaN
# 31345     100256941                UAW       2162               NaN
# 32928     103361150         UNITE-HERE        226               NaN
# 32929     103361150         UNITE-HERE        226      TWU 00000555
#
#       Participant_International  EventType  \
# 30572                       NaN  Political
# 30573                       NaN  Political
# 31345                       NaN  Political
# 32928                       NaN  Political
# 32929         Transport Workers  Political
#
#                                 EventName         Shift  \
# 30572                        L2L-NV-AD18   Single Shift
# 30573                        L2L-NV-AD18   Single Shift
# 31345                L2L-NV-AD24-10112014  Single Shift
# 32928  Captains Meeting - Southern Nevada  Single Shift
# ...

# %%
fl_writer = pd.ExcelWriter('fl_file.xlsx', engine='xlsxwriter')
nc_writer = pd.ExcelWriter('nc_file.xlsx', engine='xlsxwriter')
oh_writer = pd.ExcelWriter('oh_file.xlsx', engine='xlsxwriter')
wi_writer = pd.ExcelWriter('wi_file.xlsx', engine='xlsxwriter')
mo_writer = pd.ExcelWriter('mo_file.xlsx', engine='xlsxwriter')
pa_writer = pd.ExcelWriter('pa_file.xlsx', engine='xlsxwriter')
nv_writer = pd.ExcelWriter('fl_file.xlsx', engine='xlsxwriter')
# Out:
# Exception Exception: Exception('Exception caught in workbook destructor. Explicit close() may be required for workbook.',) in <bound method Workbook.__del__ of <xlsxwriter.workbook.Workbook object at 0x111d87910>> ignored
# Exception Exception: Exception('Exception caught in workbook destructor. Explicit close() may be required for workbook.',) in <bound method Workbook.__del__ of <xlsxwriter.workbook.Workbook object at 0x10e341b10>> ignored
# Exception Exception: Exception('Exception caught in workbook destructor. Explicit close() may be required for workbook.',) in <bound method Workbook.__del__ of <xlsxwriter.workbook.Workbook object at 0x111d876d0>> ignored
# Exception Exception: Exception('Exception caught in workbook destructor. Explicit close() may be required for workbook.',) in <bound method Workbook.__del__ of <xlsxwriter.workbook.Workbook object at 0x111d87610>> ignored
# ...

# %%
fl_file.to_excel(fl_writer, sheet_name='Sheet1')
nc_file.to_excel(nc_writer, sheet_name='Sheet1')
oh_file.to_excel(oh_writer, sheet_name='Sheet1')
wi_file.to_excel(wi_writer, sheet_name='Sheet1')
mo_file.to_excel(mo_writer, sheet_name='Sheet1')
pa_file.to_excel(pa_writer, sheet_name='Sheet1')
nv_file.to_excel(nv_writer, sheet_name='Sheet1')

# %%
fl_writer.save()
nc_writer.save()
oh_writer.save()
wi_writer.save()
mo_writer.save()
pa_writer.save()
nv_writer.save()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-54-a7286311ac98> in <module>()
# ----> 1 fl_writer.save()
#       2 nc_writer.save()
#       3 oh_writer.save()
#       4 wi_writer.save()
#       5 mo_writer.save()
#
# /anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in save(self)
#    1549         """
#    1550
# -> 1551         return self.book.close()
#    1552
#    1553     def write_cells(self, cells, sheet_name=None, startrow=0, startcol=0,
#
# /anaconda/lib/python2.7/site-packages/xlsxwriter/workbook.pyc in close(self)
#     297         if not self.fileclosed:
#     298             self.fileclosed = 1
# --> 299             self._store_workbook()
#     300
#     301     def set_size(self, width, height):
#
# /anaconda/lib/python2.7/site-packages/xlsxwriter/workbook.pyc in _store_workbook(self)
#     605         packager._set_tmpdir(self.tmpdir)
# ...

# %%
fl_writer = pd.ExcelWriter('fl_file.xlsx', engine='xlsxwriter')
fl_file.to_excel(fl_writer, sheet_name='Sheet1')
fl_writer.save()
