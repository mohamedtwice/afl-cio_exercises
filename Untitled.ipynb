# %%
import pandas as pd
import numpy as np
from xlsxwriter.utility import xl_rowcol_to_cell

# %%
v12 = pd.read_excel("Volunteers 1.1.12-12.31.12.xlsx")
v12.head()
# Out:
#    MyCampaignID International Name Local Name  Participant Local  \
# 0     100880850                CWA       3104                NaN
# 1     100880850                CWA       3104                NaN
# 2     100337155                CWA       3105                NaN
# 3     100337155                CWA       3105                NaN
# 4     100020105                CWA       3108                NaN
#
#    Participant International          EventType  \
# 0                        NaN        Legislative
# 1                        NaN          Political
# 2                        NaN          Political
# 3                        NaN          Political
# 4                        NaN  Community Service
#
#                                        EventName  Shift  \
# 0                   Working Families Lobby Corps      1
# 1                          Phone bank in Broward      1
# 2           north central florida clc phone bank      1
# ...

# %%
v12.count()
# Out:
# MyCampaignID                 62704
# International Name           37111
# Local Name                   37053
# Participant Local                0
# Participant International        0
# EventType                    62704
# EventName                    62702
# Shift                        62704
# EventDescription             32798
# StartDate                    62704
# StartTime                    62704
# EndDate                      62704
# EndTime                      62704
# Role                         62704
# Status                       62704
# Home City                    60717
# Home State                   62704
# DateRecruited                62704
# LastContactedBy                  4
# DateLastContacted                0
# InputType                        0
# dtype: int64
